# %%
import pandas as pd
import numpy as np

# %%
dataset1 = pd.read_csv("s3994666_dataset1_solution.csv")
dataset2 = pd.read_csv("s3994666_dataset2.csv")

# %%
dataset1.head(n=10)
# Out:
#          Id                                              Title  \
# 0  70215060                              Sales Bid Coordinator
# 1  71749951     Primary Teachers  Nailsea, Yatton, Congresbury
# 2  69080174            Internal Technical Engineer  Heat Pumps
# 3  67638009     Regional Sales Manager : PPE and Gas Detectors
# 4  68217496                           Senior Assembly Engineer
# 5  69967015     Associate Civil Infrastructure Design Engineer
# 6  66600487       Sales Advisor  **** an hour  Immediate Start
# 7  66925309  Service Desk Analyst  Active Directory, Citrix...
# 8  69001320                           Field Sales (Home based)
# 9  70216327                       Risk Manager (Junior/Senior)
#
#             Location                                          Company  \
# 0             surrey                                        CBSbutler
# 1  weston-super-mare  Hays Specialist Recruitment   Further Education
# ...

# %%
dataset2.head(n=10)
# Out:
#                                        Job Title              Organisation  \
# 0            Nursing Home Manager  Thames Ditton      Liquid Personnel Ltd
# 1  Deputy Manager  Nursing Home  RGN  Shrewsbury      Liquid Personnel Ltd
# 2     Deputy Manager  Nursing Home (RGN)  London      Liquid Personnel Ltd
# 3    Deputy Manager (RGN)  Nursing Home  Bristol      Liquid Personnel Ltd
# 4                              RGN or RMN  Wigan                Eden Brown
# 5          Staff Nurse in Elderly (RGN)  Bromley  Aaron Millar Recruitment
# 6          Practice Nurses Band 5  Northallerton           Hays Healthcare
# 7                          RGN or RMN  Liverpool                Eden Brown
# 8       **** Clinical Nurse Advisors  York  York           Hays Healthcare
# 9                         Scrub Nurse  Maidstone    Compass Associates Ltd
#
#    Monthly Payment Contract Type                Category              Closing  \
# ...

# %%
# Renaming columns in dataset2 to match those in dataset1
dataset2.rename(columns={
    'Job Title': 'Title',
    'Organisation': 'Company',
    'Monthly Payment': 'Salary',
    'Contract Type': 'ContractType',
    'Closing': 'CloseDate',
    'Full-Time Equivalent (FTE)': 'ContractTime',
    'Opening': 'OpenDate'
}, inplace=True)

# Convert Monthly Payment to annual Salary
dataset2['Salary'] = dataset2['Salary'] * 12

# Map 'Full-Time Equivalent (FTE)' to 'ContractTime' values
fte_to_contract_time = {
    'FULL TIME': 'full_time',
    'PART TIME': 'part_time'
}
dataset2['ContractTime'] = dataset2['ContractTime'].map(fte_to_contract_time).fillna('non-specified')

# Generate unique IDs for dataset2 since it lacks 'Id'
max_id = dataset1['Id'].max()
new_ids = range(max_id + 1, max_id + 1 + len(dataset2))
dataset2['Id'] = new_ids

# Adjust the order of columns to match dataset1
columns_order = dataset1.columns

# Adding a 'SourceName' placeholder to dataset2 to match the schema completely
dataset2['SourceName'] = 'jobhuntlisting.com'

# Now reordering dataset2 columns to match dataset1
dataset2 = dataset2[columns_order]

# Display the first few rows of both datasets to confirm alignment
dataset1.head()
# Out:
#          Id                                           Title  \
# 0  70215060                           Sales Bid Coordinator
# 1  71749951  Primary Teachers  Nailsea, Yatton, Congresbury
# 2  69080174         Internal Technical Engineer  Heat Pumps
# 3  67638009  Regional Sales Manager : PPE and Gas Detectors
# 4  68217496                        Senior Assembly Engineer
#
#             Location                                          Company  \
# 0             surrey                                        CBSbutler
# 1  weston-super-mare  Hays Specialist Recruitment   Further Education
# 2         derbyshire                 Bennett and Game Recruitment LTD
# 3                 uk                        On Target Recruitment Ltd
# 4             durham                  Baltic Recruitment Services Ltd
#
#     ContractType ContractTime          Category   Salary             OpenDate  \
# 0  non-specified    permanent  Engineering Jobs  24000.0  2013-03-01 00:00:00
# ...

# %%
dataset2.head()
# Out:
#          Id                                          Title       Location  \
# 0  72705204            Nursing Home Manager  Thames Ditton  Thames Ditton
# 1  72705205  Deputy Manager  Nursing Home  RGN  Shrewsbury     Shrewsbury
# 2  72705206     Deputy Manager  Nursing Home (RGN)  London         London
# 3  72705207    Deputy Manager (RGN)  Nursing Home  Bristol        Bristol
# 4  72705208                              RGN or RMN  Wigan          Wigan
#
#                 Company ContractType   ContractTime                Category  \
# 0  Liquid Personnel Ltd          NaN  non-specified  Healthcare and Nursing
# 1  Liquid Personnel Ltd          NaN  non-specified  Healthcare and Nursing
# 2  Liquid Personnel Ltd          NaN  non-specified  Healthcare and Nursing
# 3  Liquid Personnel Ltd          NaN  non-specified  Healthcare and Nursing
# 4            Eden Brown          NaN  non-specified  Healthcare and Nursing
#
# ...

# %%
# Replace NaN values with 'non-specified'
integrated_dataset= integrated_dataset.fillna('non-specified')

# Now we can merge the datasets
integrated_dataset = pd.concat([dataset1, dataset2], ignore_index=True)

# Display the first few rows of the integrated dataset to confirm the merge
integrated_dataset.head()
# Out:
#          Id                                           Title  \
# 0  70215060                           Sales Bid Coordinator
# 1  71749951  Primary Teachers  Nailsea, Yatton, Congresbury
# 2  69080174         Internal Technical Engineer  Heat Pumps
# 3  67638009  Regional Sales Manager : PPE and Gas Detectors
# 4  68217496                        Senior Assembly Engineer
#
#             Location                                          Company  \
# 0             surrey                                        CBSbutler
# 1  weston-super-mare  Hays Specialist Recruitment   Further Education
# 2         derbyshire                 Bennett and Game Recruitment LTD
# 3                 uk                        On Target Recruitment Ltd
# 4             durham                  Baltic Recruitment Services Ltd
#
#     ContractType ContractTime          Category   Salary             OpenDate  \
# 0  non-specified    permanent  Engineering Jobs  24000.0  2013-03-01 00:00:00
# ...

# %%
# Save the integrated dataset to a CSV file
integrated_dataset.to_csv('s3994666_integrated_dataset.csv', index=False)

# %%
df = pd.read_csv('s3994666_integrated_dataset.csv')
df.head(n=20)
# Out:
#           Id                                              Title  \
# 0   70215060                              Sales Bid Coordinator
# 1   71749951     Primary Teachers  Nailsea, Yatton, Congresbury
# 2   69080174            Internal Technical Engineer  Heat Pumps
# 3   67638009     Regional Sales Manager : PPE and Gas Detectors
# 4   68217496                           Senior Assembly Engineer
# 5   69967015     Associate Civil Infrastructure Design Engineer
# 6   66600487       Sales Advisor  **** an hour  Immediate Start
# 7   66925309  Service Desk Analyst  Active Directory, Citrix...
# 8   69001320                           Field Sales (Home based)
# 9   70216327                       Risk Manager (Junior/Senior)
# 10  70760781                   Year ****/**** Classroom Teacher
# 11  69083216  Project Manager  Automation / Dudley / ****k  ...
# 12  67369050          Compliance Engineer  Chemical Engineering
# 13  69017467                    Senior Systems Support Engineer
# ...

# %%
df.tail(n=20)
# Out:
#              Id                                              Title  \
# 55683  72710184                     Healthcare Development Manager
# 55684  72710185  Senior Medical Writers: Step up to Team Leader...
# 55685  72710186  Medical Affairs  Clinical Research Physician J...
# 55686  72710187                          Clinical Sales Specialist
# 55687  72710188  Medical Devices  Regulatory Affairs Manager Jo...
# 55688  72710189              SAS Programmer  All Levels  Permanent
# 55689  72710190  Pharmaceutical  Analytical Team Leader Jobs in...
# 55690  72710191                         Senior Quality Auditor GCP
# 55691  72710192  Territory Sales Manager: South Midlands / Card...
# 55692  72710193  Clinical Product Specialist: South Midlands / ...
# 55693  72710194                            Senior Med Info Officer
# 55694  72710195                    Territory Manager  Orthopaedics
# 55695  72710196                       Territory Manager North West
# ...
